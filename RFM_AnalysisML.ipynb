# %%
import pandas as pd
import numpy as np

# %%
import datetime as dt

# %%
data = pd.read_csv('Ecommerce_Data.csv')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    7981  CA-2014-103800  03-01-2014  07-01-2014  Standard Class    DP-13000
# 1     740  CA-2014-112326  04-01-2014  08-01-2014  Standard Class    PO-19195
# 2     741  CA-2014-112326  04-01-2014  08-01-2014  Standard Class    PO-19195
# 3     742  CA-2014-112326  04-01-2014  08-01-2014  Standard Class    PO-19195
# 4    1760  CA-2014-141817  05-01-2014  12-01-2014  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data.shape
# Out:
# (9994, 22)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Price', 'Quantity', 'Discount', 'Profit', 'Sales'],
#       dtype='object')

# %%
data.columns = [i.replace(" ","_") for i in data.columns]

# %%
data.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Price', 'Quantity', 'Discount', 'Profit', 'Sales'],
#       dtype='object')

# %% [markdown]
# # Recency

# %%
R_data = data.loc[ : ,['Customer_ID', 'Customer_Name','Order_Date']]

# %%
R_data.head(10)
# Out:
#   Customer_ID     Customer_Name  Order_Date
# 0    DP-13000     Darren Powers  03-01-2014
# 1    PO-19195     Phillina Ober  04-01-2014
# 2    PO-19195     Phillina Ober  04-01-2014
# 3    PO-19195     Phillina Ober  04-01-2014
# 4    MB-18085        Mick Brown  05-01-2014
# 5    LS-17230  Lycoris Saunders  06-01-2014
# 6    JO-15145     Jack O'Briant  06-01-2014
# 7    ME-17320     Maria Etezadi  06-01-2014
# 8    ME-17320     Maria Etezadi  06-01-2014
# 9    ME-17320     Maria Etezadi  06-01-2014

# %%
R_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    9994 non-null   object
#  1   Customer_Name  9994 non-null   object
#  2   Order_Date     9994 non-null   object
# dtypes: object(3)
# memory usage: 234.4+ KB

# %%
R_data['Order_Date'] = pd.to_datetime(R_data['Order_Date'], format='%d-%m-%Y')

# %%
R_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    9994 non-null   object
#  1   Customer_Name  9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 234.4+ KB

# %%
R_data.head()
# Out:
#   Customer_ID  Customer_Name Order_Date
# 0    DP-13000  Darren Powers 2014-01-03
# 1    PO-19195  Phillina Ober 2014-01-04
# 2    PO-19195  Phillina Ober 2014-01-04
# 3    PO-19195  Phillina Ober 2014-01-04
# 4    MB-18085     Mick Brown 2014-01-05

# %%
R_data = R_data.sort_values(by = ['Customer_ID','Order_Date'], ascending = [True,False])

# %%
R_data.head(20)
# Out:
#      Customer_ID Customer_Name Order_Date
# 7847    AA-10315    Alex Avila 2017-06-29
# 7848    AA-10315    Alex Avila 2017-06-29
# 4283    AA-10315    Alex Avila 2016-03-03
# 4284    AA-10315    Alex Avila 2016-03-03
# 4285    AA-10315    Alex Avila 2016-03-03
# 4286    AA-10315    Alex Avila 2016-03-03
# 3317    AA-10315    Alex Avila 2015-10-04
# 1107    AA-10315    Alex Avila 2014-09-15
# 1108    AA-10315    Alex Avila 2014-09-15
# 273     AA-10315    Alex Avila 2014-03-31
# 274     AA-10315    Alex Avila 2014-03-31
# 9759    AA-10375  Allen Armold 2017-12-11
# 9760    AA-10375  Allen Armold 2017-12-11
# 9761    AA-10375  Allen Armold 2017-12-11
# 8426    AA-10375  Allen Armold 2017-09-07
# 8427    AA-10375  Allen Armold 2017-09-07
# 6139    AA-10375  Allen Armold 2016-11-14
# 6140    AA-10375  Allen Armold 2016-11-14
# 6141    AA-10375  Allen Armold 2016-11-14
# 5075    AA-10375  Allen Armold 2016-07-10

# %%
from datetime import date

# %%
current_date = date.today()
print(current_date)
# Out:
# 2024-10-15

# %%
R_data['present_date'] = current_date

# %%
R_data.head()
# Out:
#      Customer_ID Customer_Name Order_Date present_date
# 7847    AA-10315    Alex Avila 2017-06-29   2024-10-15
# 7848    AA-10315    Alex Avila 2017-06-29   2024-10-15
# 4283    AA-10315    Alex Avila 2016-03-03   2024-10-15
# 4284    AA-10315    Alex Avila 2016-03-03   2024-10-15
# 4285    AA-10315    Alex Avila 2016-03-03   2024-10-15

# %%
R_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 7847 to 957
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    9994 non-null   object
#  1   Customer_Name  9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   present_date   9994 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 390.4+ KB

# %%
R_data['present_date'] = pd.to_datetime(R_data['present_date'])

# %%
R_data['no_of_days'] = R_data['present_date'] - R_data['Order_Date']

# %%
R_data.head()
# Out:
#      Customer_ID Customer_Name Order_Date present_date no_of_days
# 7847    AA-10315    Alex Avila 2017-06-29   2024-10-15  2665 days
# 7848    AA-10315    Alex Avila 2017-06-29   2024-10-15  2665 days
# 4283    AA-10315    Alex Avila 2016-03-03   2024-10-15  3148 days
# 4284    AA-10315    Alex Avila 2016-03-03   2024-10-15  3148 days
# 4285    AA-10315    Alex Avila 2016-03-03   2024-10-15  3148 days

# %%
R_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 7847 to 957
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    9994 non-null   object
#  1   Customer_Name  9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   present_date   9994 non-null   datetime64[ns]
#  4   no_of_days     9994 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), object(2), timedelta64[ns](1)
# memory usage: 468.5+ KB

# %%
#How to convert a timedel
R_data['no_of_days'] = R_data['no_of_days'].replace("days","").astype('int64')

# %%
R_data.head()
# Out:
#      Customer_ID Customer_Name Order_Date present_date          no_of_days
# 273     AA-10315    Alex Avila 2014-03-31   2024-09-19  330480000000000000
# 274     AA-10315    Alex Avila 2014-03-31   2024-09-19  330480000000000000
# 7847    AA-10315    Alex Avila 2017-06-29   2024-09-19  228009600000000000
# 7848    AA-10315    Alex Avila 2017-06-29   2024-09-19  228009600000000000
# 1107    AA-10315    Alex Avila 2014-09-15   2024-09-19  315964800000000000

# %%
# Keep only the most recent transaction for each customer
recency_data = R_data.groupby('Customer_ID').first().reset_index()

# %% [markdown]
# ## frequency

# %%
# Calculate frequency by counting the number of orders for each customer
frequency_data = R_data.groupby('Customer_ID').agg({'Order_Date': 'count'}).reset_index()
frequency_data.columns = ['Customer_ID', 'frequency']

# %%
# Merge with recency data
RFM_data = pd.merge(recency_data, frequency_data, on='Customer_ID')

# %%
RFM_data.head(20)
# Out:
#    Customer_ID         Customer_Name Order_Date present_date no_of_days  \
# 0     AA-10315            Alex Avila 2017-06-29   2024-10-15  2665 days
# 1     AA-10375          Allen Armold 2017-12-11   2024-10-15  2500 days
# 2     AA-10480          Andrew Allen 2017-04-15   2024-10-15  2740 days
# 3     AA-10645         Anna Andreadi 2017-11-05   2024-10-15  2536 days
# 4     AB-10015         Aaron Bergman 2016-11-10   2024-10-15  2896 days
# 5     AB-10060       Adam Bellavance 2017-11-06   2024-10-15  2535 days
# 6     AB-10105         Adrian Barton 2017-11-19   2024-10-15  2522 days
# 7     AB-10150           Aimee Bixby 2017-11-19   2024-10-15  2522 days
# 8     AB-10165           Alan Barnes 2017-12-05   2024-10-15  2506 days
# 9     AB-10255  Alejandro Ballentine 2017-07-17   2024-10-15  2647 days
# 10    AB-10600             Ann Blume 2017-11-10   2024-10-15  2531 days
# 11    AC-10420         Alyssa Crouse 2017-05-12   2024-10-15  2713 days
# ...

# %% [markdown]
# ## monetary

# %%
# Assuming you have 'Sales' column in your data representing purchase amount
monetary_data = data.groupby('Customer_ID').agg({'Sales': 'sum'}).reset_index()
monetary_data.columns = ['Customer_ID', 'monetary']

# %%
RFM_data.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Order_Date', 'present_date',
#        'no_of_days', 'frequency'],
#       dtype='object')

# %%
# Merge with the existing RFM data
RFM_data = pd.merge(RFM_data, monetary_data, on='Customer_ID')

# Display the RFM data for the first 10 customers
RFM_data[['Customer_ID', 'Customer_Name', 'no_of_days', 'frequency', 'monetary']].head(10)
# Out:
#   Customer_ID         Customer_Name no_of_days  frequency    monetary
# 0    AA-10315            Alex Avila  2665 days         11   16072.344
# 1    AA-10375          Allen Armold  2500 days         15    2733.630
# 2    AA-10480          Andrew Allen  2740 days         12    5493.736
# 3    AA-10645         Anna Andreadi  2536 days         18   22926.705
# 4    AB-10015         Aaron Bergman  2896 days          6    1984.080
# 5    AB-10060       Adam Bellavance  2535 days         18   35389.780
# 6    AB-10105         Adrian Barton  2522 days         20  143852.909
# 7    AB-10150           Aimee Bixby  2522 days         12    3109.642
# 8    AB-10165           Alan Barnes  2506 days         14    3623.614
# 9    AB-10255  Alejandro Ballentine  2647 days         14    2396.164

# %%
RFM_data.head(20)
# Out:
#    Customer_ID         Customer_Name Order_Date present_date no_of_days  \
# 0     AA-10315            Alex Avila 2017-06-29   2024-10-15  2665 days
# 1     AA-10375          Allen Armold 2017-12-11   2024-10-15  2500 days
# 2     AA-10480          Andrew Allen 2017-04-15   2024-10-15  2740 days
# 3     AA-10645         Anna Andreadi 2017-11-05   2024-10-15  2536 days
# 4     AB-10015         Aaron Bergman 2016-11-10   2024-10-15  2896 days
# 5     AB-10060       Adam Bellavance 2017-11-06   2024-10-15  2535 days
# 6     AB-10105         Adrian Barton 2017-11-19   2024-10-15  2522 days
# 7     AB-10150           Aimee Bixby 2017-11-19   2024-10-15  2522 days
# 8     AB-10165           Alan Barnes 2017-12-05   2024-10-15  2506 days
# 9     AB-10255  Alejandro Ballentine 2017-07-17   2024-10-15  2647 days
# 10    AB-10600             Ann Blume 2017-11-10   2024-10-15  2531 days
# 11    AC-10420         Alyssa Crouse 2017-05-12   2024-10-15  2713 days
# ...

# %%
# Create quartile-based scoring for Recency, Frequency, and Monetary
RFM_data['R_Score'] = pd.qcut(RFM_data['no_of_days'], 4, labels=[4, 3, 2, 1])
RFM_data['F_Score'] = pd.qcut(RFM_data['frequency'].rank(method='first'), 4, labels=[1, 2, 3, 4])
RFM_data['M_Score'] = pd.qcut(RFM_data['monetary'].rank(method='first'), 4, labels=[1, 2, 3, 4])

# %%
RFM_data.head(20)
# Out:
#    Customer_ID         Customer_Name Order_Date present_date no_of_days  \
# 0     AA-10315            Alex Avila 2017-06-29   2024-10-15  2665 days
# 1     AA-10375          Allen Armold 2017-12-11   2024-10-15  2500 days
# 2     AA-10480          Andrew Allen 2017-04-15   2024-10-15  2740 days
# 3     AA-10645         Anna Andreadi 2017-11-05   2024-10-15  2536 days
# 4     AB-10015         Aaron Bergman 2016-11-10   2024-10-15  2896 days
# 5     AB-10060       Adam Bellavance 2017-11-06   2024-10-15  2535 days
# 6     AB-10105         Adrian Barton 2017-11-19   2024-10-15  2522 days
# 7     AB-10150           Aimee Bixby 2017-11-19   2024-10-15  2522 days
# 8     AB-10165           Alan Barnes 2017-12-05   2024-10-15  2506 days
# 9     AB-10255  Alejandro Ballentine 2017-07-17   2024-10-15  2647 days
# 10    AB-10600             Ann Blume 2017-11-10   2024-10-15  2531 days
# 11    AC-10420         Alyssa Crouse 2017-05-12   2024-10-15  2713 days
# ...

# %%
# Combine scores to get the RFM score
RFM_data['RFM_Score'] = RFM_data['R_Score'].astype(str) + RFM_data['F_Score'].astype(str) + RFM_data['M_Score'].astype(str)

# %%
# Show the RFM data with RFM scores for first 10 customers
RFM_data[['Customer_ID', 'Customer_Name', 'RFM_Score']].head(10)
# Out:
#   Customer_ID         Customer_Name RFM_Score
# 0    AA-10315            Alex Avila       123
# 1    AA-10375          Allen Armold       431
# 2    AA-10480          Andrew Allen       122
# 3    AA-10645         Anna Andreadi       344
# 4    AB-10015         Aaron Bergman       111
# 5    AB-10060       Adam Bellavance       344
# 6    AB-10105         Adrian Barton       344
# 7    AB-10150           Aimee Bixby       321
# 8    AB-10165           Alan Barnes       431
# 9    AB-10255  Alejandro Ballentine       231

# %%
# Define customer segments based on RFM Score
def segment_customer(df):
    if df['RFM_Score'] == '444':
        return 'Best Customers'
    elif df['RFM_Score'].startswith('4'):
        return 'Loyal Customers'
    elif df['RFM_Score'].startswith('1'):
        return 'At Risk'
    else:
        return 'Others'

RFM_data['Customer_Segment'] = RFM_data.apply(segment_customer, axis=1)

# Show segmented customer data
RFM_data[['Customer_ID', 'Customer_Name', 'RFM_Score', 'Customer_Segment']].head(10)
# Out:
#   Customer_ID         Customer_Name RFM_Score Customer_Segment
# 0    AA-10315            Alex Avila       123          At Risk
# 1    AA-10375          Allen Armold       431  Loyal Customers
# 2    AA-10480          Andrew Allen       122          At Risk
# 3    AA-10645         Anna Andreadi       344           Others
# 4    AB-10015         Aaron Bergman       111          At Risk
# 5    AB-10060       Adam Bellavance       344           Others
# 6    AB-10105         Adrian Barton       344           Others
# 7    AB-10150           Aimee Bixby       321           Others
# 8    AB-10165           Alan Barnes       431  Loyal Customers
# 9    AB-10255  Alejandro Ballentine       231           Others
